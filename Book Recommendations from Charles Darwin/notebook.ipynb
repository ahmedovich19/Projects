# %% [markdown]
# ## 1. Darwin's bibliography
# <p><img src="https://assets.datacamp.com/production/project_607/img/CharlesDarwin.jpg" alt="Charles Darwin" width="300px"></p>
# <p>Charles Darwin is one of the few universal figures of science. His most renowned work is without a doubt his "<em>On the Origin of Species</em>" published in 1859 which introduced the concept of natural selection. But Darwin wrote many other books on a wide range of topics, including geology, plants or his personal life. In this notebook, we will automatically detect how closely related his books are to each other.</p>
# <p>To this purpose, we will develop the bases of <strong>a content-based book recommendation system</strong>, which will determine which books are close to each other based on how similar the discussed topics are. The methods we will use are commonly used in text- or documents-heavy industries such as legal, tech or customer support to perform some common task such as text classification or handling search engine queries.</p>
# <p>Let's take a look at the books we'll use in our recommendation system.</p>

# %%
# Import library
import glob

# The books files are contained in this folder
folder = "datasets/"
# List all the .txt files and sort them alphabetically
files = glob.glob(folder + "*.txt")
files.sort()
files
# Out:
# ['datasets/Autobiography.txt',
#  'datasets/CoralReefs.txt',
#  'datasets/DescentofMan.txt',
#  'datasets/DifferentFormsofFlowers.txt',
#  'datasets/EffectsCrossSelfFertilization.txt',
#  'datasets/ExpressionofEmotionManAnimals.txt',
#  'datasets/FormationVegetableMould.txt',
#  'datasets/FoundationsOriginofSpecies.txt',
#  'datasets/GeologicalObservationsSouthAmerica.txt',
#  'datasets/InsectivorousPlants.txt',
#  'datasets/LifeandLettersVol1.txt',
#  'datasets/LifeandLettersVol2.txt',
#  'datasets/MonographCirripedia.txt',
#  'datasets/MonographCirripediaVol2.txt',
#  'datasets/MovementClimbingPlants.txt',
#  'datasets/OriginofSpecies.txt',
#  'datasets/PowerMovementPlants.txt',
#  'datasets/VariationPlantsAnimalsDomestication.txt',
#  'datasets/VolcanicIslands.txt',
#  'datasets/VoyageBeagle.txt']

# %% [markdown]
# ## 2. Load the contents of each book into Python
# <p>As a first step, we need to load the content of these books into Python and do some basic pre-processing to facilitate the downstream analyses. We call such a collection of texts <strong>a corpus</strong>. We will also store the titles for these books for future reference and print their respective length to get a gauge for their contents.</p>

# %%
# Import libraries
import re, os

# Initialize the object that will contain the texts and titles
txts = []
titles = []

for n in files:
    # Open each file
    f = open(n, encoding='utf-8-sig')
    read_f = f.read()
    # Remove all non-alpha-numeric characters
    pattern = '[\W_]+'
    f_without_alpha_num = re.sub(pattern,' ', read_f)
    # Store the texts and titles of the books in two separate lists
    titles.append(os.path.basename(n).replace('.txt',''))
    txts.append(f_without_alpha_num)

# Print the length, in characters, of each book
[len(t) for t in txts]
# Out:
# [123231,
#  496068,
#  1776539,
#  617088,
#  913713,
#  624232,
#  335920,
#  523021,
#  797401,
#  901406,
#  1047518,
#  1010643,
#  767492,
#  1660866,
#  298319,
#  916267,
#  1093567,
#  1043499,
#  341447,
#  1149574]

# %% [markdown]
# ## 3. Find "On the Origin of Species"
# <p>For the next parts of this analysis, we will often check the results returned by our method for a given book. For consistency, we will refer to Darwin's most famous book: "<em>On the Origin of Species</em>." Let's find to which index this book is associated.</p>

# %%
# Browse the list containing all the titles
for i in range(len(titles)):
    # Store the index if the title is "OriginofSpecies"
    ori = 15

# Print the stored index
print(titles[ori])
# Out:
# OriginofSpecies

# %% [markdown]
# ## 4. Tokenize the corpus
# <p>As a next step, we need to transform the corpus into a format that is easier to deal with for the downstream analyses. We will tokenize our corpus, i.e., transform each text into a list of the individual words (called tokens) it is made of. To check the output of our process, we will print the first 20 tokens of "<em>On the Origin of Species</em>".</p>

# %%
# Define a list of stop words
stoplist = set('for a of the and to in to be which some is at that we i who whom show via may my our might as well'.split())

# Convert the text to lower case 
txts_lower_case = [text.lower() for text in txts]

# Transform the text into tokens 
txts_split = [text_lower_case.split() for text_lower_case in txts_lower_case]

# Remove tokens which are part of the list of stop words
texts = [[word for word in text if word not in stoplist] for text in txts_split]
# Print the first 20 tokens for the "On the Origin of Species" book
texts[ori][:20]
# Out:
# ['on',
#  'origin',
#  'species',
#  'but',
#  'with',
#  'regard',
#  'material',
#  'world',
#  'can',
#  'least',
#  'go',
#  'so',
#  'far',
#  'this',
#  'can',
#  'perceive',
#  'events',
#  'are',
#  'brought',
#  'about']

# %% [markdown]
# ## 5. Stemming of the tokenized corpus
# <p>If you have read <em>On the Origin of Species</em>, you will have noticed that Charles Darwin can use different words to refer to a similar concept. For example, the concept of selection can be described by words such as <em>selection</em>, <em>selective</em>, <em>select</em> or <em>selects</em>. This will dilute the weight given to this concept in the book and potentially bias the results of the analysis.</p>
# <p>To solve this issue, it is a common practice to use a <strong>stemming process</strong>, which will group together the inflected forms of a word so they can be analysed as a single item: <strong>the stem</strong>. In our <em>On the Origin of Species</em> example, the words related to the concept of selection would be gathered under the <em>select</em> stem.</p>
# <p>As we are analysing 20 full books, the stemming algorithm can take several minutes to run and, in order to make the process faster, we will directly load the final results from a pickle file and review the method used to generate it.</p>

# %%
import pickle

# Load the stemmed tokens list from the pregenerated pickle file
texts_stem = pickle.load(open('datasets/texts_stem.p','rb'))

# Print the 20 first stemmed tokens from the "On the Origin of Species" book
texts_stem[ori][:20]
# Out:
# ['on',
#  'origin',
#  'speci',
#  'but',
#  'with',
#  'regard',
#  'materi',
#  'world',
#  'can',
#  'least',
#  'go',
#  'so',
#  'far',
#  'thi',
#  'can',
#  'perceiv',
#  'event',
#  'are',
#  'brought',
#  'about']

# %% [markdown]
# ## 6. Building a bag-of-words model
# <p>Now that we have transformed the texts into stemmed tokens, we need to build models that will be useable by downstream algorithms.</p>
# <p>First, we need to will create a universe of all words contained in our corpus of Charles Darwin's books, which we call <em>a dictionary</em>. Then, using the stemmed tokens and the dictionary, we will create <strong>bag-of-words models</strong> (BoW) of each of our texts. The BoW models will represent our books as a list of all uniques tokens they contain associated with their respective number of occurrences. </p>
# <p>To better understand the structure of such a model, we will print the five first elements of one of the "<em>On the Origin of Species</em>" BoW model.</p>

# %%
# Load the functions allowing to create and use dictionaries
from gensim import corpora

# Create a dictionary from the stemmed tokens
dictionary = corpora.Dictionary(texts_stem)

# Create a bag-of-words model for each book, using the previously generated dictionary
bows = [dictionary.doc2bow(text) for text in txts_split]

# Print the first five elements of the On the Origin of species' BoW model
print(bows[ori][:5])
# Out:
# [(0, 11), (5, 51), (6, 1), (8, 2), (21, 1)]

# %% [markdown]
# ## 7. The most common words of a given book
# <p>The results returned by the bag-of-words model is certainly easy to use for a computer but hard to interpret for a human. It is not straightforward to understand which stemmed tokens are present in a given book from Charles Darwin, and how many occurrences we can find.</p>
# <p>In order to better understand how the model has been generated and visualize its content, we will transform it into a DataFrame and display the 10 most common stems for the book "<em>On the Origin of Species</em>".</p>

# %%
# Import pandas to create and manipulate DataFrames
import pandas as pd

# Convert the BoW model for "On the Origin of Species" into a DataFrame
df_bow_origin = pd.DataFrame(bows[ori])
# Add the column names to the DataFrame
df_bow_origin.columns = ['index', 'occurrences']

# Add a column containing the token corresponding to the dictionary index
df_bow_origin['token'] = df_bow_origin['index'].apply(lambda x: dictionary[x])

# Sort the DataFrame by descending number of occurrences and print the first 10 values
df_bow_origin = df_bow_origin.sort_values('occurrences', ascending=False)
df_bow_origin.head(10)
# Out:
#       index  occurrences token
# 1542   4479         7907    of
# 1944   6005         4455   and
# 2932  24478         3632    to
# 437    1168         1769  have
# 103     286         1662    be
# 662    1736         1558    on
# 158     393         1362    by
# 666    1747         1201    or
# 75      218         1140   are
# 382    1043         1137  from

# %% [markdown]
# ## 8. Build a tf-idf model
# <p>If it wasn't for the presence of the stem "<em>speci</em>", we would have a hard time to guess this BoW model comes from the <em>On the Origin of Species</em> book. The most recurring words are, apart from few exceptions, very common and unlikely to carry any information peculiar to the given book. We need to use an additional step in order to determine which tokens are the most specific to a book.</p>
# <p>To do so, we will use a <strong>tf-idf model</strong> (term frequency–inverse document frequency). This model defines the importance of each word depending on how frequent it is in this text and how infrequent it is in all the other documents. As a result, a high tf-idf score for a word will indicate that this word is specific to this text.</p>
# <p>After computing those scores, we will print the 10 words most specific to the "<em>On the Origin of Species</em>" book (i.e., the 10 words with the highest tf-idf score).</p>

# %%
# Load the gensim functions that will allow us to generate tf-idf models
from gensim.models import TfidfModel

# Generate the tf-idf model
model = TfidfModel(bows)

# Print the model for "On the Origin of Species"
print(model[bows[ori]])
# Out:
# [(8, 0.00038130539001769465), (21, 0.0010692891356179812), (23, 0.003202364944480171), (27, 0.0012081373313477019), (28, 0.0048035474167202556), (31, 0.0016011824722400854), (35, 0.001898694225305978), (36, 0.001898694225305978), (51, 0.0016588101793759927), (54, 0.003797388450611956), (56, 0.0044442158270781495), (57, 0.00019065269500884732), (63, 0.005152735053945462), (64, 0.0009532634750442366), (66, 0.00038130539001769465), (67, 0.0044442158270781495), (68, 0.003797388450611956), (75, 0.002576367526972731), (76, 0.0008294050896879964), (78, 0.007804194279405294), (84, 0.0010692891356179812), (91, 0.006635240717503971), (95, 0.001898694225305978), (97, 0.004147025448439982), (99, 0.013332647481234448), (111, 0.004194359290194642), (115, 0.00285979042513271), (118, 0.03132543226595096), (123, 0.0885500880331789), (130, 0.010269167316455467), (137, 0.037463498783268004), (144, 0.014102858558502879), (157, 0.0027413108376586), (165, 0.014839916804619796), (172, 0.04072804673092777), (176, 0.006291538935291962), (186, 0.016205479075752025), (194, 0.0019065269500884731), (198, 0.0016588101793759927), (209, 0.0023496950037073714), (212, 0.0024784850351150154), (214, 0.03483501376689584), (215, 0.040632987153483284), (220, 0.004699390007414743), (221, 0.008950123504557417), (222, 0.0034057726166607273), (224, 0.014410642250160767), (230, 0.009607094833440511), (233, 0.0007626107800353893), (235, 0.014839916804619796), (236, 0.003902097139702647), (244, 0.006666323740617224), (245, 0.011110539567695374), (246, 0.002097179645097321), (247, 0.0013257296127299157), (249, 0.005696082675917934), (251, 0.015608388558810587), (252, 0.005696082675917934), (253, 0.0012081373313477019), (254, 0.0054826216753172), (258, 0.001143916170053084), (269, 0.0022221079135390748), (271, 0.0015664633358049142), (278, 0.005302918450919663), (280, 0.003977188838189747), (283, 0.0044442158270781495), (285, 0.003202364944480171), (288, 0.005935966721847918), (290, 0.009493471126529889), (291, 0.0034057726166607273), (296, 0.009061029985107764), (300, 0.0031329266716098284), (301, 0.0007832316679024571), (302, 0.007954377676379494), (303, 0.007804194279405294), (304, 0.003902097139702647), (308, 0.003050443120141557), (311, 0.003050443120141557), (313, 0.014410642250160767), (323, 0.008903950082771879), (325, 0.02476681529262789), (327, 0.0032410958151504045), (329, 0.02834004279670004), (339, 0.0026514592254598315), (344, 0.0026514592254598315), (345, 0.003797388450611956), (346, 0.00038130539001769465), (349, 0.0010692891356179812), (350, 0.027220102028081453), (351, 0.008950123504557417), (354, 0.003797388450611956), (356, 0.0023496950037073714), (359, 0.011392165351835869), (362, 0.0022221079135390748), (363, 0.0024784850351150154), (367, 0.004475061752278709), (369, 0.17332441725604786), (370, 0.03580049401822967), (371, 0.0009532634750442366), (372, 0.004475061752278709), (374, 0.0019065269500884731), (375, 0.003622401205168099), (376, 0.012140090852488083), (380, 0.008888431654156299), (387, 0.0013257296127299157), (388, 0.006811545233321455), (389, 0.0013257296127299157), (391, 0.004475061752278709), (399, 0.0026691377301238627), (406, 0.02576367526972731), (409, 0.006265853343219657), (411, 0.0013257296127299157), (418, 0.005982140143633458), (424, 0.011134875197578921), (426, 0.009280107289109411), (429, 0.0016588101793759927), (431, 0.0008294050896879964), (435, 0.016913922638867825), (436, 0.006666323740617224), (442, 0.01590875535275899), (448, 0.03524542505561057), (454, 0.004475061752278709), (456, 0.004832549325390807), (463, 0.0334927778506455), (464, 0.005152735053945462), (465, 0.0016011824722400854), (470, 0.0034057726166607273), (486, 0.003902097139702647), (493, 0.0013257296127299157), (497, 0.015554755394773523), (502, 0.011931566514569242), (505, 0.01824691197313592), (510, 0.007485023949325867), (512, 0.008960676665415824), (527, 0.002967983360923959), (529, 0.022713718369171253), (531, 0.0026514592254598315), (533, 0.0044442158270 ...

# %% [markdown]
# ## 9. The results of the tf-idf model
# <p>Once again, the format of those results is hard to interpret for a human. Therefore, we will transform it into a more readable version and display the 10 most specific words for the "<em>On the Origin of Species</em>" book.</p>

# %%
# Convert the tf-idf model for "On the Origin of Species" into a DataFrame
df_tfidf = pd.DataFrame(model[bows[ori]])

# Name the columns of the DataFrame id and score
df_tfidf.columns =['id','score']

# Add the tokens corresponding to the numerical indices for better readability
df_tfidf['token'] = df_tfidf['id'].apply(lambda x: dictionary[x])

# Sort the DataFrame by descending tf-idf score and print the first 10 rows.
df_tfidf = df_tfidf.sort_values('score',ascending=False)
print(df_tfidf[:10])
# Out:
#          id     score       token
# 276    1092  0.222420     glacial
# 1909  10108  0.197535      pigeon
# 96      369  0.173324       breed
# 472    1878  0.163288      pollen
# 2538  24445  0.155888   sanguinea
# 977    3254  0.153260         bee
# 2317  16224  0.140475    silurian
# 1668   7190  0.139495    creation
# 203     822  0.124655      embryo
# 1930  10321  0.124438  progenitor

# %% [markdown]
# ## 10. Compute distance between texts
# <p>The results of the tf-idf algorithm now return stemmed tokens which are specific to each book. We can, for example, see that topics such as selection, breeding or domestication are defining "<em>On the Origin of Species</em>" (and yes, in this book, Charles Darwin talks quite a lot about pigeons too). Now that we have a model associating tokens to how specific they are to each book, we can measure how related to books are between each other.</p>
# <p>To this purpose, we will use a measure of similarity called <strong>cosine similarity</strong> and we will visualize the results as a distance matrix, i.e., a matrix showing all pairwise distances between Darwin's books.</p>

# %%
# Load the library allowing similarity computations
from gensim import similarities

# Compute the similarity matrix (pairwise distance between all texts)
sims = similarities.MatrixSimilarity(model[bows])

# Transform the resulting list into a dataframe
sim_df = pd.DataFrame(list(sims))

# Add the titles of the books as columns and index of the dataframe
sim_df.columns = titles
sim_df.index = titles

# Print the resulting matrix
sim_df
# Out:
#                                      Autobiography  CoralReefs  DescentofMan  \
# Autobiography                             1.000000    0.033562      0.092304
# CoralReefs                                0.033562    1.000000      0.011780
# DescentofMan                              0.092304    0.011780      1.000000
# DifferentFormsofFlowers                   0.041295    0.002808      0.052236
# EffectsCrossSelfFertilization             0.023458    0.002086      0.031448
# ExpressionofEmotionManAnimals             0.093128    0.005343      0.194170
# FormationVegetableMould                   0.045808    0.024477      0.045146
# FoundationsOriginofSpecies                0.037097    0.015687      0.094051
# GeologicalObservationsSouthAmerica        0.030241    0.040843      0.012785
# InsectivorousPlants                       0.017472    0.004676      0.018740
# LifeandLettersVol1                        0.367407    0.024803      0.056564
# LifeandLettersVol2                        0.217925    0.013965      0.071240
# MonographCirripedia                       0.004167    0.004437      0.046744
# MonographCirripediaVol2                   0.007117    0.007527      0.044720
# MovementClimbingPlants                    0.006192    0.001379      0.009464
# OriginofSpecies                           0.091622    0.040407      0.225523
# PowerMovementPlants                       0.010612    0.004661      0.029166
# VariationPlantsAnimalsDomestication       0.040815    0.013799      0.224881
# VolcanicIslands                           0.037441    0.053224      0.011882
# VoyageBeagle                              0.173577    0.206337      0.129153
#
#                                      DifferentFormsofFlowers  \
# Autobiography                                       0.041295
# CoralReefs                                          0.002808
# DescentofMan                                        0.052236
# DifferentFormsofFlowers                             1.000000
# EffectsCrossSelfFertilization                       0.308068
# ExpressionofEmotionManAnimals                       0.010682
# FormationVegetableMould                             0.021236
# FoundationsOriginofSpecies                          0.023443
# GeologicalObservationsSouthAmerica                  0.004424
# InsectivorousPlants                                 0.023824
# LifeandLettersVol1                                  0.012910
# LifeandLettersVol2                                  0.042217
# MonographCirripedia                                 0.005448
# MonographCirripediaVol2                             0.004823
# MovementClimbingPlants                              0.019595
# OriginofSpecies                                     0.178308
# PowerMovementPlants                                 0.026215
# VariationPlantsAnimalsDomestication                 0.069482
# VolcanicIslands                                     0.005327
# VoyageBeagle                                        0.012325
#
#                                      EffectsCrossSelfFertilization  \
# Autobiography                                             0.023458
# CoralReefs                                                0.002086
# DescentofMan                                              0.031448
# DifferentFormsofFlowers                                   0.308068
# EffectsCrossSelfFertilization                             1.000000
# ExpressionofEmotionManAnimals                             0.011453
# FormationVegetableMould                                   0.036102
# FoundationsOriginofSpecies                                0.020625
# GeologicalObservationsSouthAmerica                        0.003202
# InsectivorousPlants                                       0.017430
# LifeandLettersVol1                                        0.011686
# LifeandLettersVol2                                        0.022399
# MonographCirripedia                                       0.002015
# MonographCirripediaVol2                                   0.002698
# MovementClimbingPlants                                    0.026099
# OriginofSpecies                                           0.118789
# PowerMovementPlants                                       0.073162
# VariationPlantsAnimalsDomestication                       0.044202
# VolcanicIslands                                           0.002915
# VoyageBeagle                                              0.020514
#
#                                      ExpressionofEmotionManAnimals  \
# Autobiography                                             0.093128
# CoralReefs                                                0.005343
# DescentofMan                                              0.194170
# DifferentFormsofFlowers                                   0.010682
# EffectsCrossSelfFertilization                             0.011453
# ExpressionofEmotionManAnimals                             1.000000
# FormationVegetableMould                                   0.031549
# FoundationsOriginofSpecies                                0.033668
# GeologicalObservationsSouthAmerica                        0.005998
# InsectivorousPlants                                       0.026954
# LifeandLettersVol1                                        0.062583
# LifeandLettersVol2                                        0.046697
# MonographCirripedia                                       0.013303
# MonographCirripediaVol2                                   0.024684
# MovementClimbingPlants                                    0.008715
# OriginofSpecies                                           0.069795
# PowerMovementPlants                                       0.025932
# VariationPlantsAnimalsDomestication                       0.086389
# VolcanicIslands                                           0.007466
# VoyageBeagle                                              0.096740
#
#                                      FormationVegetableMould  \
# Autobiography                                       0.045808
# CoralReefs                                          0.024477
# DescentofMan                                        0.045146
# DifferentFormsofFlowers                             0.021236
# EffectsCrossSelfFertilization                       0.036102
# ExpressionofEmotionManAnimals                       0.031549
# FormationVegetableMould                             1.000000
# FoundationsOriginofSpecies                          0.018205
# GeologicalObservationsSouthAmerica                  0.063293
# InsectivorousPlants                                 0.076720
# LifeandLettersVol1                                  0.027300
# LifeandLettersVol2                                  0.026605
# MonographCirripedia                                 0.019252
# MonographCirripediaVol2                             0.025882
# MovementClimbingPlants                              0.014822
# OriginofSpecies                                     0.063782
# PowerMovementPlants                                 0.053540
# VariationPlantsAnimalsDomestication                 0.041851
# VolcanicIslands                                     0.042578
# VoyageBeagle                                        0.101003
#
#                                      FoundationsOriginofSpecies  \
# Autobiography                                          0.037097
# CoralReefs                                             0.015687
# DescentofMan                                           0.094051
# DifferentFormsofFlowers                                0.023443
# EffectsCrossSelfFertilization                          0.020625
# ExpressionofEmotionManAnimals                          0.033668
# FormationVegetableMould                                0.018205
# FoundationsOriginofSpecies                             1.000000
# GeologicalObservationsSouthAmerica                     0.020312
# InsectivorousPlants                                    0.010915
# LifeandLettersVol1                                     0.033677
# LifeandLettersVol2                                     0.028390
# MonographCirripedia                                    0.004749
# MonographCirripediaVol2                                0.008111
# MovementClimbingPlants                                 0.004183
# OriginofSpecies                                        0.166747
# PowerMovementPlants                                    0.010903
# VariationPlantsAnimalsDomestication                    0.100214
# VolcanicIslands                                        0.015772
# VoyageBeagle                                           0.063679
#
#                                      GeologicalObservationsSouthAmerica  \
# Autobiography                                                  0.030241
# CoralReefs                                                     0.040843
# DescentofMan                                                   0.012785
# DifferentFormsofFlowers                                        0.004424
# EffectsCrossSelfFertilization                                  0.003202
# ExpressionofEmotionManAnimals                                  0.005998
# FormationVegetableMould                                        0.063293
# FoundationsOriginofSpecies                                     0.020312
# GeologicalObservationsSouthAmerica                             1.000000
# InsectivorousPlants                                            0.010396
# LifeandLettersVol1                                             0.026029
# LifeandLettersVol2                                             0.010281
# MonographCirripedia                                            0.004781
# MonographCirripediaVol2                                        0.010895
# MovementClimbingPlants                                         0.002561
# OriginofSpecies                                                0.067336
# PowerMovementPlants                                            0.006546
# VariationPlantsAnimalsDomestication                            0.017811
# VolcanicIslands                                                0.337053
# VoyageBeagle                                                   0.331957
#
#                                      InsectivorousPlants  LifeandLettersVol1  \
# Autobiography                                   0.017472            0.367407
# CoralReefs                                      0.004676            0.024803
# DescentofMan                                    0.018740            0.056564
# DifferentFormsofFlowers                         0.023824            0.012910
# EffectsCrossSelfFertilization                   0.017430            0.011686
# ExpressionofEmotionManAnimals                   0.026954            0.062583
# FormationVegetableMould                         0.076720            0.027300
# FoundationsOriginofSpecies                      0.010915            0.033677
# GeologicalObservationsSouthAmerica              0.010396            0.026029
# InsectivorousPlants                             1.000000            0.009209
# LifeandLettersVol1                              0.009209            1.000000
# LifeandLettersVol2                              0.029739            0.914785
# MonographCirripedia                             0.015871            0.003650
# MonographCirripediaVol2                         0.022400            0.011469
# MovementClimbingPlants                          0.077138            0.005980
# OriginofSpecies                                 0.026294            0.079463
# PowerMovementPlants                             0.077809            0.010813
# VariationPlantsAnimalsDomestication             0.026031            0.041285
# VolcanicIslands                                 0.013244            0.024831
# VoyageBeagle                                    0.029525            0.152524
#
#                                      LifeandLettersVol2  MonographCirripedia  \
# Autobiography                                  0.217925             0.004167
# CoralReefs                                     0.013965             0.004437
# DescentofMan                                   0.071240             0.046744
# DifferentFormsofFlowers                        0.042217             0.005448
# EffectsCrossSelfFertilization                  0.022399             0.002015
# ExpressionofEmotionManAnimals                  0.046697             0.013303
# FormationVegetableMould                        0.026605             0.019252
# FoundationsOriginofSpecies                     0.028390             0.004749
# GeologicalObservationsSouthAmerica             0.010281             0.004781
# InsectivorousPlants                            0.029739             0.015871
# LifeandLettersVol1                             0.914785             0.003650
# LifeandLettersVol2                             1.000000             0.003032
# MonographCirripedia                            0.003032             1.000000
# MonographCirripediaVol2                        0.010434             0.512506
# MovementClimbingPlants                         0.011480             0.004666
# OriginofSpecies                                0.070657             0.018773
# PowerMovementPlants                            0.012897             0.027061
# VariationPlantsAnimalsDomestication            0.036708             0.024025
# VolcanicIslands                                0.011935             0.005896
# VoyageBeagle                                   0.081062             0.010937
#
#                                      MonographCirripediaVol2  \
# Autobiography                                       0.007117
# CoralReefs                                          0.007527
# DescentofMan                                        0.044720
# DifferentFormsofFlowers                             0.004823
# EffectsCrossSelfFertilization                       0.002698
# ExpressionofEmotionManAnimals                       0.024684
# FormationVegetableMould                             0.025882
# FoundationsOriginofSpecies                          0.008111
# GeologicalObservationsSouthAmerica                  0.010895
# InsectivorousPlants                                 0.022400
# LifeandLettersVol1                                  0.011469
# LifeandLettersVol2                                  0.010434
# MonographCirripedia                                 0.512506
# MonographCirripediaVol2                             1.000000
# MovementClimbingPlants                              0.008961
# OriginofSpecies                                     0.024554
# PowerMovementPlants                                 0.050920
# VariationPlantsAnimalsDomestication                 0.034390
# VolcanicIslands                                     0.008681
# VoyageBeagle                                        0.019904
#
#                                      MovementClimbingPlants  OriginofSpecies  \
# Autobiography                                      0.006192         0.091622
# CoralReefs                                         0.001379         0.040407
# DescentofMan                                       0.009464         0.225523
# DifferentFormsofFlowers                            0.019595         0.178308
# EffectsCrossSelfFertilization                      0.026099         0.118789
# ExpressionofEmotionManAnimals                      0.008715         0.069795
# FormationVegetableMould                            0.014822         0.063782
# FoundationsOriginofSpecies                         0.004183         0.166747
# GeologicalObservationsSouthAmerica                 0.002561         0.067336
# InsectivorousPlants                                0.077138         0.026294
# LifeandLettersVol1                                 0.005980         0.079463
# LifeandLettersVol2                                 0.011480         0.070657
# MonographCirripedia                                0.004666         0.018773
# MonographCirripediaVol2                            0.008961         0.024554
# MovementClimbingPlants                             1.000000         0.012904
# OriginofSpecies                                    0.012904         1.000000
# PowerMovementPlants                                0.078658         0.026485
# VariationPlantsAnimalsDomestication                0.013369         0.355521
# VolcanicIslands                                    0.003316         0.054744
# VoyageBeagle                                       0.018377         0.176807
#
#                                      PowerMovementPlants  \
# Autobiography                                   0.010612
# CoralReefs                                      0.004661
# DescentofMan                                    0.029166
# DifferentFormsofFlowers                         0.026215
# EffectsCrossSelfFertilization                   0.073162
# ExpressionofEmotionManAnimals                   0.025932
# FormationVegetableMould                         0.053540
# FoundationsOriginofSpecies                      0.010903
# GeologicalObservationsSouthAmerica              0.006546
# InsectivorousPlants                             0.077809
# LifeandLettersVol1                              0.010813
# LifeandLettersVol2                              0.012897
# MonographCirripedia                             0.027061
# MonographCirripediaVol2                         0.050920
# MovementClimbingPlants                          0.078658
# OriginofSpecies                                 0.026485
# PowerMovementPlants                             1.000000
# VariationPlantsAnimalsDomestication             0.033143
# VolcanicIslands                                 0.007221
# VoyageBeagle                                    0.045351
#
#                                      VariationPlantsAnimalsDomestication  \
# Autobiography                                                   0.040815
# CoralReefs                                                      0.013799
# DescentofMan                                                    0.224881
# DifferentFormsofFlowers                                         0.069482
# EffectsCrossSelfFertilization                                   0.044202
# ExpressionofEmotionManAnimals                                   0.086389
# FormationVegetableMould                                         0.041851
# FoundationsOriginofSpecies                                      0.100214
# GeologicalObservationsSouthAmerica                              0.017811
# InsectivorousPlants                                             0.026031
# LifeandLettersVol1                                              0.041285
# LifeandLettersVol2                                              0.036708
# MonographCirripedia                                             0.024025
# MonographCirripediaVol2                                         0.034390
# MovementClimbingPlants                                          0.013369
# OriginofSpecies                                                 0.355521
# PowerMovementPlants                                             0.033143
# VariationPlantsAnimalsDomestication                             1.000000
# VolcanicIslands                                                 0.016615
# VoyageBeagle                                                    0.112652
#
#                                      VolcanicIslands  VoyageBeagle
# Autobiography                               0.037441      0.173577
# CoralReefs                                  0.053224      0.206337
# DescentofMan                                0.011882      0.129153
# DifferentFormsofFlowers                     0.005327      0.012325
# EffectsCrossSelfFertilization               0.002915      0.020514
# ExpressionofEmotionManAnimals               0.007466      0.096740
# FormationVegetableMould                     0.042578      0.101003
# FoundationsOriginofSpecies                  0.015772      0.063679
# GeologicalObservationsSouthAmerica          0.337053      0.331957
# InsectivorousPlants                         0.013244      0.029525
# LifeandLettersVol1                          0.024831      0.152524
# LifeandLettersVol2                          0.011935      0.081062
# MonographCirripedia                         0.005896      0.010937
# MonographCirripediaVol2                     0.008681      0.019904
# MovementClimbingPlants                      0.003316      0.018377
# OriginofSpecies                             0.054744      0.176807
# PowerMovementPlants                         0.007221      0.045351
# VariationPlantsAnimalsDomestication         0.016615      0.112652
# VolcanicIslands                             1.000000      0.145385
# VoyageBeagle                                0.145385      1.000000

# %% [markdown]
# ## 11. The book most similar to "On the Origin of Species"
# <p>We now have a matrix containing all the similarity measures between any pair of books from Charles Darwin! We can now use this matrix to quickly extract the information we need, i.e., the distance between one book and one or several others. </p>
# <p>As a first step, we will display which books are the most similar to "<em>On the Origin of Species</em>," more specifically we will produce a bar chart showing all books ranked by how similar they are to Darwin's landmark work.</p>

# %%
# This is needed to display plots in a notebook
# %matplotlib inline

# Import libraries
import matplotlib.pyplot as plt

# Select the column corresponding to "On the Origin of Species" and 
v = sim_df['OriginofSpecies']

# Sort by ascending scores
v_sorted = v.sort_values(ascending=True)

# Plot this data has a horizontal bar plot
v_sorted.plot.barh()

# Modify the axes labels and plot title for a better readability
plt.xlabel('Score')
plt.ylabel('Book')
plt.title('The book most similar to "On the Origin of Species".')

# %% [markdown]
# ## 12. Which books have similar content?
# <p>This turns out to be extremely useful if we want to determine a given book's most similar work. For example, we have just seen that if you enjoyed "<em>On the Origin of Species</em>," you can read books discussing similar concepts such as "<em>The Variation of Animals and Plants under Domestication</em>" or "<em>The Descent of Man, and Selection in Relation to Sex</em>." If you are familiar with Darwin's work, these suggestions will likely seem natural to you. Indeed, <em>On the Origin of Species</em> has a whole chapter about domestication and <em>The Descent of Man, and Selection in Relation to Sex</em> applies the theory of natural selection to human evolution. Hence, the results make sense.</p>
# <p>However, we now want to have a better understanding of the big picture and see how Darwin's books are generally related to each other (in terms of topics discussed). To this purpose, we will represent the whole similarity matrix as a dendrogram, which is a standard tool to display such data. <strong>This last approach will display all the information about book similarities at once.</strong> For example, we can find a book's closest relative but, also, we can visualize which groups of books have similar topics (e.g., the cluster about Charles Darwin personal life with his autobiography and letters). If you are familiar with Darwin's bibliography, the results should not surprise you too much, which indicates the method gives good results. Otherwise, next time you read one of the author's book, you will know which other books to read next in order to learn more about the topics it addressed.</p>

# %%
# Import libraries
from scipy.cluster import hierarchy

# Compute the clusters from the similarity matrix,
# using the Ward variance minimization algorithm
Z = hierarchy.linkage(sims,'ward')

# Display this result as a horizontal dendrogram
hierarchy.dendrogram(Z,leaf_font_size=8, labels=sim_df.index, orientation="left")
plt.show()
